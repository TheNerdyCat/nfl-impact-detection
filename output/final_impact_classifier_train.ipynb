# %% [markdown]
# ## NFL First and Future - Impact Detection
# -------------------
# # Final Impact Classifier | Train
#
#  - Can we have a meta-classifier that predicts probability of an impact occurring. This can then fit in the pipeline as another meta-feature or can interact with final predictions.
#  - Cross-validation. When splitting, we should consider game, team, play, AND camera angle.
#  - Get rid of all non-helmet impact types? More augmentations for non-helmet impact types?
#
#
#
#
# #### CLEANING STEPS:
#  1. `impactType` - shoulder values
#  - Bin player positions and add as a feature
